# %%
# 파이썬에서
from qdrant_client import QdrantClient
client = QdrantClient(host="localhost", port=6333, api_key="my-secure-portfolio-key-2025", prefer_grpc=False, https=False)

# 10-K 관련 컬렉션 모두 삭제
collections = client.get_collections()
for c in collections.collections:
    if '10-k' in c.name.lower():
        client.delete_collection(c.name)
        print(f"삭제: {c.name}")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_31636\3350826676.py:3: UserWarning: Api key is used with an insecure connection.
#   client = QdrantClient(host="localhost", port=6333, api_key="my-secure-portfolio-key-2025", prefer_grpc=False, https=False)
# 삭제: 10-k-q4-2023-as-filed_main
